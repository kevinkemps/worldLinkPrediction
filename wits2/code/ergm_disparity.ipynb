# %%
library(statnet)
library(stats)
# Out:
# Loading required package: tergm
#
# Loading required package: ergm
#
# Loading required package: network
#
#
# 'network' 1.19.0 (2024-12-08), part of the Statnet Project
# * 'news(package="network")' for changes since last version
# * 'citation("network")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
#
# 'ergm' 4.8.1 (2025-01-20), part of the Statnet Project
# * 'news(package="ergm")' for changes since last version
# * 'citation("ergm")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
# 'ergm' 4 is a major update that introduces some backwards-incompatible
# changes. Please type 'news(package="ergm")' for a list of major
# changes.
#
#
# Loading required package: networkDynamic
#
#
# 'networkDynamic' 0.11.5 (2024-11-21), part of the Statnet Project
# * 'news(package="networkDynamic")' for changes since last version
# * 'citation("networkDynamic")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
# Registered S3 method overwritten by 'tergm':
#   method                   from
#   simulate_formula.network ergm
#
#
# 'tergm' 4.2.1 (2024-10-08), part of the Statnet Project
# * 'news(package="tergm")' for changes since last version
# * 'citation("tergm")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
#
# Attaching package: 'tergm'
#
#
# The following object is masked from 'package:ergm':
#
#     snctrl
#
#
# Loading required package: ergm.count
#
#
# 'ergm.count' 4.1.2 (2024-06-15), part of the Statnet Project
# * 'news(package="ergm.count")' for changes since last version
# * 'citation("ergm.count")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
# Loading required package: sna
#
# Loading required package: statnet.common
#
#
# Attaching package: 'statnet.common'
#
#
# The following object is masked from 'package:ergm':
#
#     snctrl
#
#
# The following objects are masked from 'package:base':
#
#     attr, order
#
#
# sna: Tools for Social Network Analysis
# Version 2.8 created on 2024-09-07.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#  For citation information, type citation("sna").
#  Type help(package="sna") to get started.
#
#
# Loading required package: tsna
#
#
# 'statnet' 2019.6 (2019-06-13), part of the Statnet Project
# * 'news(package="statnet")' for changes since last version
# * 'citation("statnet")' for citation information
# * 'https://statnet.org' for help, support, and other information
#
#
# Warning message:
# "unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'"

# %%
el_dist
# Out:
#       source target dist       log_dist
# 1     AFG    AFG      303.7614 5.716243
# 2     AFG    AGO     7607.8000 8.936929
# 3     AFG    ALB     4342.1170 8.376117
# 4     AFG    ARE     1813.6150 7.503077
# 5     AFG    ARG    15298.5000 9.635510
# 6     AFG    ARM     2266.1500 7.725838
# 7     AFG    ATG    12297.0900 9.417118
# 8     AFG    AUS    11433.4900 9.344302
# 9     AFG    AUT     4568.0980 8.426852
# 10    AFG    AZE     1822.2170 7.507809
# 11    AFG    BDI     5930.0570 8.687789
# 12    AFG    BEL     5416.1210 8.597135
# 13    AFG    BEN     7481.0060 8.920123
# 14    AFG    BFA     7497.5950 8.922338
# 15    AFG    BGD     2376.9780 7.773585
# 16    AFG    BGR     4043.0050 8.304744
# 17    AFG    BHR     2004.4340 7.603117
# 18    AFG    BHS    12518.5800 9.434969
# 19    AFG    BIH     4428.6140 8.395842
# 20    AFG    BLR     3880.9000 8.263822
# 21    AFG    BOL    15349.9500 9.638867
# 22    AFG    BRA    13771.7600 9.530375
# 23    AFG    BRN     5741.1410 8.655413
# 24    AFG    BTN     2103.5010 7.651358
# 25    AFG    BWA     8023.7670 8.990163
# 26    AFG    CAF     6188.3150 8.730418
# 27    AFG    CAN    10768.8900 9.284417
# 28    AFG    CHE     5247.0430 8.565420
# 29    AFG    CHL    16353.9000 9.702222
# 30    AFG    CHN     4180.4380 8.338171
# ⋮     ⋮      ⋮      ⋮          ⋮
# 27527 ZWE    SLV    13638.5700 9.520657
# 27528 ZWE    STP     3335.3540 8.112334
# 27529 ZWE    SUR     9825.0660 9.192692
# 27530 ZWE    SVK     7474.6510 8.919273
# 27531 ZWE    SVN     7304.9240 8.896304
# 27532 ZWE    SWE     8669.4470 9.067560
# 27533 ZWE    SWZ      946.0821 6.852329
# 27534 ZWE    SYC     3037.0680 8.018648
# 27535 ZWE    TCD     3776.8670 8.236650
# 27536 ZWE    TGO     4216.9040 8.346856
# 27537 ZWE    THA     8393.0700 9.035162
# 27538 ZWE    TJK     7417.8870 8.911650
# 27539 ZWE    TKM     6835.0690 8.829822
# 27540 ZWE    TON    14833.7500 9.604660
# 27541 ZWE    TTO    10645.4900 9.272892
# 27542 ZWE    TUN     6465.8930 8.774296
# 27543 ZWE    TUR     6555.4050 8.788045
# 27544 ZWE    TZA     1515.2790 7.323355
# 27545 ZWE    UGA     2028.8960 7.615247
# 27546 ZWE    UKR     7596.3620 8.935425
# 27547 ZWE    URY     8646.8600 9.064952
# 27548 ZWE    USA    12552.1300 9.437646
# 27549 ZWE    UZB     7664.5810 8.944365
# 27550 ZWE    VCT    10699.6600 9.277967
# 27551 ZWE    VNM     9231.1780 9.130342
# 27552 ZWE    WSM    14465.2000 9.579501
# 27553 ZWE    YEM     3971.4740 8.286893
# 27554 ZWE    ZAF     2186.2060 7.689923
# 27555 ZWE    ZMB      396.8041 5.983443
# 27556 ZWE    ZWE      235.1193 5.460093

# %%
el_dist = read.csv("../data/common/dist.csv", stringsAsFactors = FALSE)
el_dist$log_dist = log(el_dist$dist)
dist_net = network(el_dist, directed = TRUE, matrix.type = "edgelist")
set.edge.value(dist_net, "dist", el_dist$dist)
set.edge.value(dist_net, "log_dist", el_dist$log_dist)
dist_net
# Out:
# Error: `loops` is `FALSE`, but `x` contains loops.
# The following values are affected:
# 	- `x[1, 1:2]`
# 	- `x[168, 1:2]`
# 	- `x[335, 1:2]`
# 	- `x[502, 1:2]`
# 	- `x[669, 1:2]`
# 	- `x[836, 1:2]`
# Traceback:
#
# 1. as.network(x, directed = directed, hyper = hyper, loops = loops,
#  .     multiple = multiple, bipartite = bipartite, ...)
# 2. as.network.data.frame(x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite,
#  .     ...)
# 3. .validate_edge_df(edges = x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite)
# 4. stop("`loops` is `FALSE`, but `x` contains loops.", "\nThe following values are affected:",
#  .     paste("\n\t-", sprintf("`x[%d, 1:2]`", .head(loop_rows))),
#  .     call. = FALSE)
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "`loops` is `FALSE`, but `x` contains loops.\nThe following values are affected:\n\t- `x[1, 1:2]`\n\t- `x[168, 1:2]`\n\t- `x[335, 1:2]`\n\t- `x[502, 1:2]`\n\t- `x[669, 1:2]`\n\t- `x[836, 1:2]`",
#  .     base::quote(NULL))

# %%
el_diplomatic = read.csv("../data/2011/features/dip_exhange_clean.csv", stringsAsFactors = FALSE)
diplomatic_exchange_net = network(el_diplomatic, directed = TRUE, matrix.type = "edgelist")
diplomatic_exchange_net
# Out:
# Error: `loops` is `FALSE`, but `x` contains loops.
# The following values are affected:
# 	- `x[1540, 1:2]`
# 	- `x[1579, 1:2]`
# Traceback:
#
# 1. as.network(x, directed = directed, hyper = hyper, loops = loops,
#  .     multiple = multiple, bipartite = bipartite, ...)
# 2. as.network.data.frame(x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite,
#  .     ...)
# 3. .validate_edge_df(edges = x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite)
# 4. stop("`loops` is `FALSE`, but `x` contains loops.", "\nThe following values are affected:",
#  .     paste("\n\t-", sprintf("`x[%d, 1:2]`", .head(loop_rows))),
#  .     call. = FALSE)
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "`loops` is `FALSE`, but `x` contains loops.\nThe following values are affected:\n\t- `x[1540, 1:2]`\n\t- `x[1579, 1:2]`",
#  .     base::quote(NULL))

# %%
el_colony = read.csv("../data/common/colonization_el.csv", stringsAsFactors = FALSE)
colony_net = network(el_colony, directed = TRUE, matrix.type = "edgelist")
set.edge.value(colony_net, "colonization", el_colony$colonization)
colony_net
# Out:
# Error: `loops` is `FALSE`, but `x` contains loops.
# The following values are affected:
# 	- `x[1, 1:2]`
# 	- `x[168, 1:2]`
# 	- `x[335, 1:2]`
# 	- `x[502, 1:2]`
# 	- `x[669, 1:2]`
# 	- `x[836, 1:2]`
# Traceback:
#
# 1. as.network(x, directed = directed, hyper = hyper, loops = loops,
#  .     multiple = multiple, bipartite = bipartite, ...)
# 2. as.network.data.frame(x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite,
#  .     ...)
# 3. .validate_edge_df(edges = x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite)
# 4. stop("`loops` is `FALSE`, but `x` contains loops.", "\nThe following values are affected:",
#  .     paste("\n\t-", sprintf("`x[%d, 1:2]`", .head(loop_rows))),
#  .     call. = FALSE)
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "`loops` is `FALSE`, but `x` contains loops.\nThe following values are affected:\n\t- `x[1, 1:2]`\n\t- `x[168, 1:2]`\n\t- `x[335, 1:2]`\n\t- `x[502, 1:2]`\n\t- `x[669, 1:2]`\n\t- `x[836, 1:2]`",
#  .     base::quote(NULL))

# %%
el = read.csv("../data/2011/edgelist_disparity.csv", stringsAsFactors = FALSE)
nl = read.csv("../data/2011/nodelist.csv", stringsAsFactors = FALSE)

# %%
nl$gdp_us_dollar <- log(nl$gdp_us_dollar)
nl$area <- log(nl$area)
nl$population <- log(nl$population)
nl$gdp_per_capita <- log(nl$gdp_per_capita)

# %%
nl$gdp_us_dollar = as.numeric(scale(nl$gdp_us_dollar))
nl$gdp_growth = as.numeric(scale(nl$gdp_growth))
nl$inflation_rate = as.numeric(scale(nl$inflation_rate))
nl$population = as.numeric(scale(nl$population))
nl$gdp_per_capita = as.numeric(scale(nl$gdp_per_capita))
nl$agriculture_forestry_fishing_of_gdp = as.numeric(scale(nl$agriculture_forestry_fishing_of_gdp))
nl$industry_of_gdp = as.numeric(scale(nl$industry_of_gdp))
nl$merchandise_of_gdp = as.numeric(scale(nl$merchandise_of_gdp))
nl$net_barter_of_trade = as.numeric(scale(nl$net_barter_of_trade))
nl$foreign_direct_investment_inflows = as.numeric(scale(nl$foreign_direct_investment_inflows))

# %%
net = network(el, directed = TRUE, matrix.type = 'edgelist', vertex.attr=nl, vertex.attrnames=colnames(nl), ignore.eval = FALSE, names.eval='trade')
set.edge.value(net, "trade", el$weight)
net
# Out:
# Error: `loops` is `FALSE`, but `x` contains loops.
# The following values are affected:
# 	- `x[2578, 1:2]`
# Traceback:
#
# 1. as.network(x, directed = directed, hyper = hyper, loops = loops,
#  .     multiple = multiple, bipartite = bipartite, ...)
# 2. as.network.data.frame(x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite,
#  .     ...)
# 3. .validate_edge_df(edges = x, directed = directed, hyper = hyper,
#  .     loops = loops, multiple = multiple, bipartite = bipartite)
# 4. stop("`loops` is `FALSE`, but `x` contains loops.", "\nThe following values are affected:",
#  .     paste("\n\t-", sprintf("`x[%d, 1:2]`", .head(loop_rows))),
#  .     call. = FALSE)
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "`loops` is `FALSE`, but `x` contains loops.\nThe following values are affected:\n\t- `x[2578, 1:2]`",
#  .     base::quote(NULL))

# %%
net
# Out:
# Error: object 'net' not found
# Traceback:

# %%
set.seed(19746)
model = ergm(
                        net ~
                        edges +
                        mutual +
                        triangles + 
                        nodecov("gdp_us_dollar") + # world bank
                        absdiff("gdp_us_dollar") + # world bank
                        nodecov("inflation_rate") + # world bank
                        absdiff("inflation_rate") + # world bank
                        nodecov("gdp_growth") + # world bank
                        absdiff("gdp_growth") + # world bank
                        nodematch("landlocked") + # http://www.cepii.fr/CEPII/en/bdd_modele/download.asp?id=6
                        nodematch("langoff_1") + # http://www.cepii.fr/CEPII/en/bdd_modele/download.asp?id=6
                        edgecov(diplomatic_exchange_net) + # https://pardee.du.edu/diplomatic-representation-data-set
                        nodecov("agriculture_forestry_fishing_of_gdp") + # world bank
                        absdiff("agriculture_forestry_fishing_of_gdp") + # world bank
                        nodecov("industry_of_gdp") + # world bank
                        absdiff("industry_of_gdp") + # world bank
                        nodecov("merchandise_of_gdp") + # world bank
                        absdiff("merchandise_of_gdp") + # world bank
                        nodecov("net_barter_of_trade") + # world bank
                        absdiff("net_barter_of_trade") + # world bank
                        nodecov("foreign_direct_investment_inflows") + # world bank
                        absdiff("foreign_direct_investment_inflows") + # world bank
                        edgecov(colony_net, "colonization") +
                        edgecov(dist_net, "log_dist"),
                )
# Out:
# Error in eval(object[[2L]], envir = environment(object)): object 'net' not found
# Traceback:
#
# 1. ergm.getnetwork(formula)
# 2. eval_lhs.formula(formula)
# 3. eval(object[[2L]], envir = environment(object))
# 4. eval(object[[2L]], envir = environment(object))
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'net' not found", base::quote(eval(object[[2L]], envir = environment(object))))

# %%
summary(model)
# Out:
# Call:
# ergm(formula = net ~ edges + mutual + triangles + nodecov("gdp_us_dollar") +
#     absdiff("gdp_us_dollar") + nodecov("inflation_rate") + absdiff("inflation_rate") +
#     nodecov("gdp_growth") + absdiff("gdp_growth") + nodematch("landlocked") +
#     nodematch("langoff_1") + edgecov(diplomatic_exchange_net) +
#     nodecov("agriculture_forestry_fishing_of_gdp") + absdiff("agriculture_forestry_fishing_of_gdp") +
#     nodecov("industry_of_gdp") + absdiff("industry_of_gdp") +
#     nodecov("merchandise_of_gdp") + absdiff("merchandise_of_gdp") +
#     nodecov("net_barter_of_trade") + absdiff("net_barter_of_trade") +
#     nodecov("foreign_direct_investment_inflows") + absdiff("foreign_direct_investment_inflows") +
#     edgecov(colony_net, "colonization") + edgecov(dist_net, "log_dist"))
#
# Iterations:  5 out of 20
#
# Monte Carlo MLE Results:
#                                              Estimate Std. Error MCMC % z value
# edges                                       -4.545306   0.292507      0 -15.539
# mutual                                       0.212864   0.067819      0   3.139
# triangle                                     0.030752   0.003531      0   8.708
# nodecov.gdp_us_dollar                        0.185193   0.020931      0   8.848
# absdiff.gdp_us_dollar                        0.272567   0.024940      0  10.929
# nodecov.inflation_rate                      -0.040754   0.022979      0  -1.774
# absdiff.inflation_rate                       0.036081   0.028730      0   1.256
# nodecov.gdp_growth                          -0.010265   0.017265      0  -0.595
# absdiff.gdp_growth                          -0.027033   0.023401      0  -1.155
# nodematch.landlocked                        -0.220336   0.039726      0  -5.546
# nodematch.langoff_1                         -0.014159   0.063925      0  -0.221
# edgecov.diplomatic_exchange_net             -1.677797   0.079264      0 -21.167
# nodecov.agriculture_forestry_fishing_of_gdp -0.052345   0.022273      0  -2.350
# absdiff.agriculture_forestry_fishing_of_gdp  0.090205   0.028968      0   3.114
# nodecov.industry_of_gdp                      0.055862   0.020991      0   2.661
# absdiff.industry_of_gdp                     -0.114031   0.026439      0  -4.313
# nodecov.merchandise_of_gdp                   0.046760   0.017230      0   2.714
# absdiff.merchandise_of_gdp                  -0.031426   0.026004      0  -1.208
# nodecov.net_barter_of_trade                  0.040164   0.015878      0   2.530
# absdiff.net_barter_of_trade                 -0.090658   0.024623      0  -3.682
# nodecov.foreign_direct_investment_inflows   -1.474203   0.199127      0  -7.403
# absdiff.foreign_direct_investment_inflows    1.352387   0.200292      0   6.752
# edgecov.colonization                        -0.513982   0.603699      0  -0.851
# edgecov.log_dist                             0.190993   0.030113      0   6.342
#                                             Pr(>|z|)
# edges                                        < 1e-04 ***
# mutual                                      0.001697 **
# triangle                                     < 1e-04 ***
# nodecov.gdp_us_dollar                        < 1e-04 ***
# absdiff.gdp_us_dollar                        < 1e-04 ***
# nodecov.inflation_rate                      0.076140 .
# absdiff.inflation_rate                      0.209169
# nodecov.gdp_growth                          0.552148
# absdiff.gdp_growth                          0.248014
# nodematch.landlocked                         < 1e-04 ***
# nodematch.langoff_1                         0.824714
# edgecov.diplomatic_exchange_net              < 1e-04 ***
# nodecov.agriculture_forestry_fishing_of_gdp 0.018768 *
# absdiff.agriculture_forestry_fishing_of_gdp 0.001846 **
# nodecov.industry_of_gdp                     0.007785 **
# absdiff.industry_of_gdp                      < 1e-04 ***
# nodecov.merchandise_of_gdp                  0.006649 **
# absdiff.merchandise_of_gdp                  0.226860
# nodecov.net_barter_of_trade                 0.011419 *
# absdiff.net_barter_of_trade                 0.000232 ***
# nodecov.foreign_direct_investment_inflows    < 1e-04 ***
# absdiff.foreign_direct_investment_inflows    < 1e-04 ***
# edgecov.colonization                        0.394554
# edgecov.log_dist                             < 1e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#      Null Deviance: 37971  on 27390  degrees of freedom
#  Residual Deviance: 19042  on 27366  degrees of freedom
#
# AIC: 19090    BIC: 19287    (Smaller is better.)

# %%
set.seed(18717)
gof <- gof(model ~ model + distance + triadcensus)

# %%
gof
# Out:
# Goodness-of-fit for model statistics
#
#                                                     obs         min        mean
# edges                                        3416.00000  3209.00000  3410.04000
# mutual                                        324.00000   279.00000   322.44000
# triangle                                    13862.00000 10922.00000 13742.49000
# nodecov.gdp_us_dollar                        -821.10899 -1005.61036  -824.30231
# absdiff.gdp_us_dollar                        4366.84990  4134.51257  4364.75424
# nodecov.inflation_rate                       -143.36930  -347.63576  -150.32262
# absdiff.inflation_rate                       2884.89469  2531.02848  2875.93680
# nodecov.gdp_growth                            242.44471   -22.96250   220.93355
# absdiff.gdp_growth                           2349.80140  2111.11603  2360.09129
# nodematch.landlocked                         2032.00000  1884.00000  2027.19000
# nodematch.langoff_1                           262.00000   216.00000   256.66000
# edgecov.diplomatic_exchange_net               236.00000   191.00000   235.31000
# nodecov.agriculture_forestry_fishing_of_gdp   146.34519   -49.92135   155.31856
# absdiff.agriculture_forestry_fishing_of_gdp  3813.26078  3562.24237  3815.84541
# nodecov.industry_of_gdp                        61.69574  -165.93216    80.86949
# absdiff.industry_of_gdp                      3428.90245  3176.77660  3433.45076
# nodecov.merchandise_of_gdp                    136.73376   -86.56831   126.38212
# absdiff.merchandise_of_gdp                   3490.39619  3276.95325  3488.11759
# nodecov.net_barter_of_trade                   138.85741   -77.70032   154.18471
# absdiff.net_barter_of_trade                  3605.91541  3381.86785  3610.65774
# nodecov.foreign_direct_investment_inflows    -873.98167 -1014.86506  -861.30157
# absdiff.foreign_direct_investment_inflows    1107.53186   982.08316  1116.69289
# edgecov.colonization                            3.00000     0.00000     2.84000
# edgecov.log_dist                            30492.10207 28657.06109 30441.69804
#                                                    max MC p-value
# edges                                        3648.0000       0.98
# mutual                                        375.0000       0.92
# triangle                                    17092.0000       0.80
# nodecov.gdp_us_dollar                        -586.8589       0.98
# absdiff.gdp_us_dollar                        4703.5800       0.92
# nodecov.inflation_rate                        147.9629       0.92
# absdiff.inflation_rate                       3132.1255       0.94
# nodecov.gdp_growth                            391.3527       0.80
# absdiff.gdp_growth                           2558.3240       0.88
# nodematch.landlocked                         2195.0000       1.00
# nodematch.langoff_1                           313.0000       0.80
# edgecov.diplomatic_exchange_net               272.0000       1.00
# nodecov.agriculture_forestry_fishing_of_gdp   399.5074       0.90
# absdiff.agriculture_forestry_fishing_of_gdp  4129.9342       0.92
# nodecov.industry_of_gdp                       381.5745       0.90
# absdiff.industry_of_gdp                      3713.6793       1.00
# nodecov.merchandise_of_gdp                    387.9878       0.92
# absdiff.merchandise_of_gdp                   3745.6587       0.94
# nodecov.net_barter_of_trade                   391.5433       0.88
# absdiff.net_barter_of_trade                  3919.5357       0.98
# nodecov.foreign_direct_investment_inflows    -723.8434       0.78
# absdiff.foreign_direct_investment_inflows    1267.2163       0.88
# edgecov.colonization                            7.0000       1.00
# edgecov.log_dist                            32560.1324       0.96
#
# Goodness-of-fit for minimum geodesic distance
#
#       obs   min     mean   max MC p-value
# 1    3416  3209  3410.04  3648       0.98
# 2   15291 21018 21460.93 21819       0.00
# 3    4193  1963  2513.12  3068       0.00
# 4     128     0     2.61    31       0.00
# Inf  4362     0     3.30   165       0.00
#
# Goodness-of-fit for triad census
#
#         obs    min      mean    max MC p-value
# 003  358607 333722 352977.02 368354       0.36
# 012  254642 258449 264862.45 271294       0.00
# 102   28111  26030  30088.25  34896       0.12
# 021D  26050  16740  18253.52  20220       0.00
# 021U  26155  16572  18044.74  20508       0.00
# 021C  25343  32914  36144.67  40362       0.00
# 111D   7985   7377   8600.06   9937       0.34
# 111U  10646   7551   8657.70  10111       0.00
# 030T   5708   4316   5229.27   6329       0.22
# 030C    870   1398   1733.58   2151       0.00
# 201    1386    807   1080.45   1415       0.08
# 120D    615    507    653.27    864       0.66
# 120U   1009    552    656.47    848       0.00
# 120C   1088   1019   1310.16   1694       0.04
# 210     425    243    351.82    498       0.26
# 300      20      7     16.57     42       0.50

# %%
pdf("../reports/gof.pdf", width = 15, height = 5)
layout(matrix(c(1,2,3), nrow = 1, ncol = 3, byrow = TRUE), widths = c(5,5,5), heights = c(5,5,5))
plot(gof)
dev.off()
# Out:
# png
#   2

# %%
mcmc.diagnostics(model, which = c("plots"))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# MCMC diagnostics shown here are from the last round of simulation, prior to computation of final parameter estimates. Because the final estimates are refinements of those used for this simulation run, these diagnostics may understate model performance. To directly assess the performance of the final model on in-model statistics, please use the GOF command: gof(ergmFitObject, GOF=~model).
# plot without title

# %% [markdown]
# ### Check correlations

# %%
filtered_nl = nl[, !startsWith(colnames(nl), 'scaled') & !startsWith(colnames(nl), 'log')]
nums <- unlist(lapply(filtered_nl, is.numeric))

# %%
cor(filtered_nl[, nums])
# Out:
#                                     net_barter_of_trade inflation_rate
# net_barter_of_trade                  1.00000000          0.078314042
# inflation_rate                       0.07831404          1.000000000
# gdp_per_capita                      -0.08622343         -0.352086451
# population                           0.11855892          0.178082910
# merchandise_of_gdp                  -0.03562669         -0.008408133
# landlocked                           0.06801235          0.088971183
# foreign_direct_investment_inflows   -0.12383319         -0.105751278
# industry_of_gdp                      0.55221983          0.032595828
# agriculture_forestry_fishing_of_gdp  0.02883888          0.222426000
# gdp_growth                           0.03231466          0.002927180
# area                                 0.30959536          0.195153354
# gdp_us_dollar                        0.04813794         -0.070874068
#                                     gdp_per_capita population
# net_barter_of_trade                 -0.08622343     0.11855892
# inflation_rate                      -0.35208645     0.17808291
# gdp_per_capita                       1.00000000    -0.13956272
# population                          -0.13956272     1.00000000
# merchandise_of_gdp                   0.25033400    -0.19050854
# landlocked                          -0.28142431     0.01231352
# foreign_direct_investment_inflows    0.29165768     0.31656572
# industry_of_gdp                      0.22133883     0.14291746
# agriculture_forestry_fishing_of_gdp -0.82694513     0.14282607
# gdp_growth                          -0.11134959     0.04917145
# area                                -0.14201092     0.81832019
# gdp_us_dollar                        0.51703778     0.77535426
#                                     merchandise_of_gdp landlocked
# net_barter_of_trade                 -0.035626692        0.068012354
# inflation_rate                      -0.008408133        0.088971183
# gdp_per_capita                       0.250333998       -0.281424310
# population                          -0.190508544        0.012313521
# merchandise_of_gdp                   1.000000000        0.006623188
# landlocked                           0.006623188        1.000000000
# foreign_direct_investment_inflows    0.071711929       -0.121480619
# industry_of_gdp                      0.220117991       -0.032491018
# agriculture_forestry_fishing_of_gdp -0.293889645        0.273737883
# gdp_growth                           0.049824497        0.135857620
# area                                -0.232295249        0.107117391
# gdp_us_dollar                       -0.003863552       -0.169535753
#                                     foreign_direct_investment_inflows
# net_barter_of_trade                 -0.123833193
# inflation_rate                      -0.105751278
# gdp_per_capita                       0.291657685
# population                           0.316565717
# merchandise_of_gdp                   0.071711929
# landlocked                          -0.121480619
# foreign_direct_investment_inflows    1.000000000
# industry_of_gdp                     -0.026198518
# agriculture_forestry_fishing_of_gdp -0.193983411
# gdp_growth                           0.001240165
# area                                 0.204055687
# gdp_us_dollar                        0.459155825
#                                     industry_of_gdp
# net_barter_of_trade                  0.55221983
# inflation_rate                       0.03259583
# gdp_per_capita                       0.22133883
# population                           0.14291746
# merchandise_of_gdp                   0.22011799
# landlocked                          -0.03249102
# foreign_direct_investment_inflows   -0.02619852
# industry_of_gdp                      1.00000000
# agriculture_forestry_fishing_of_gdp -0.34277848
# gdp_growth                          -0.11465726
# area                                 0.26192618
# gdp_us_dollar                        0.26592719
#                                     agriculture_forestry_fishing_of_gdp
# net_barter_of_trade                  0.02883888
# inflation_rate                       0.22242600
# gdp_per_capita                      -0.82694513
# population                           0.14282607
# merchandise_of_gdp                  -0.29388965
# landlocked                           0.27373788
# foreign_direct_investment_inflows   -0.19398341
# industry_of_gdp                     -0.34277848
# agriculture_forestry_fishing_of_gdp  1.00000000
# gdp_growth                           0.15097043
# area                                 0.15494457
# gdp_us_dollar                       -0.40411823
#                                     gdp_growth   area        gdp_us_dollar
# net_barter_of_trade                  0.032314664  0.30959536  0.048137942
# inflation_rate                       0.002927180  0.19515335 -0.070874068
# gdp_per_capita                      -0.111349590 -0.14201092  0.517037781
# population                           0.049171448  0.81832019  0.775354257
# merchandise_of_gdp                   0.049824497 -0.23229525 -0.003863552
# landlocked                           0.135857620  0.10711739 -0.169535753
# foreign_direct_investment_inflows    0.001240165  0.20405569  0.459155825
# industry_of_gdp                     -0.114657259  0.26192618  0.265927194
# agriculture_forestry_fishing_of_gdp  0.150970431  0.15494457 -0.404118232
# gdp_growth                           1.000000000  0.01366847 -0.028226973
# area                                 0.013668471  1.00000000  0.617012407
# gdp_us_dollar                       -0.028226973  0.61701241  1.000000000

# %%
cor_results = cor(filtered_nl[, nums]) > .6
diag(cor_results) = F

# %%
col_names = colnames(cor_results)
temp = matrix('', nrow=length(col_names), ncol = length(col_names))
for (i in 1:length(col_names)) {
    for (j in 1:length(col_names)) {
        temp[i, j] = paste(col_names[i], col_names[j])
    }
}

# %%
temp[cor_results]
# Out:
# [1] "area population"          "gdp_us_dollar population"
# [3] "population area"          "gdp_us_dollar area"
# [5] "population gdp_us_dollar" "area gdp_us_dollar"

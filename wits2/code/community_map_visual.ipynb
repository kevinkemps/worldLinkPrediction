# %%
import geopandas
from geodatasets import data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries_continents = pd.read_csv("../data/countries_communities.csv")
countries_continents.set_index('country', inplace=True)

# %%
countries_continents
# Out:
#          community
# country
# AFG              2
# ALB              1
# ARE              2
# ARG              0
# ARM              1
# ...            ...
# VCT              0
# BTN              2
# KIR              2
# PLW              0
# WSM              2
#
# [166 rows x 1 columns]

# %%
#gpd_path = r"C:\Users\kevijone\OneDrive - Qualcomm\Documents\python\networkingscience\world_link_prediction\wits\ne_110m_admin_0_countries\ne_110m_admin_0_countries.shp"
gpd_path = r"C:\Users\kevijone\OneDrive - Qualcomm\Documents\python\networkingscience\world_link_prediction\wits\ne_110m_admin_0_countries.zip"
world = geopandas.read_file(gpd_path)

# %%
world = world.join(countries_continents, on='SOV_A3')

# %%
plt.figure(figsize=(15, 12))
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().set_xticks([])
plt.gca().set_yticks([])
world.plot(column='community', ax = plt.gca(), missing_kwds={'color': 'lightgrey'})
plt.savefig("../reports/community_world_map.pdf", pad_inches=0, bbox_inches='tight')
